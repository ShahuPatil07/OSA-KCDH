# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"Moderate-20240823T064003Z-001\Moderate\00000074-297469\00000074-297469[001].edf")
df
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df = pd.read_csv(r"Moderate-20240823T064003Z-001\Moderate\00000074-297469\00000074-297469[001].edf")
#       2 df
#
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(df["var_coeff"], df["category"])
plt.title("categories vs varying coefficient")
plt.show()
